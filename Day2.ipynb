# %% [markdown]
# <a href="https://colab.research.google.com/github/GIRISH2409/Day2_ML/blob/main/Day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **New Section**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#IRIS  Dataset which is predefined in python packages

data = sns.load_dataset("iris")

# %%
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
data.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
#Matplot

#Line Graph

plt.plot(data['sepal_width'])

plt.show()

# %%
plt.plot(data['sepal_length'])

# %%
plt.plot(data['petal_length'])

# %%
# Give name to x-axis and y-axis

plt.plot(data['sepal_length'])

plt.xlabel('Indexes')
plt.ylabel('lengths')

plt.title('Sepal length',fontsize=28,color="blue")
plt.show()

# %%
plt.plot(data['sepal_length'],color="red" ,label = "sepal length")
plt.plot(data['sepal_width'],color ="blue" , label="sepal width")
plt.xlabel('Indexes')
plt.ylabel('sepal counts')

plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.grid()
plt.plot(data['sepal_length'],color="red" ,label = "sepal length",linestyle="--")
plt.plot(data['sepal_width'],color ="blue" , label="sepal width" ,marker="*")
plt.xlabel('Indexes')
plt.ylabel('sepal counts')
plt.legend()
plt.show()

# %%
# seaborn and matplotlib combinly

# tips dataset available in default

tips = sns.load_dataset("tips")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# create bar graph for iris data set

plt.bar(data['species'], data['petal_length'])

plt.show()
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
plt.bar(tips["day"],tips["size"])
plt.show()

# %%
#pie chart

x= tips['day']

y=tips['total_bill']

# %%
explode = [0,0,0.1];
import matplotlib.pyplot as plt
import seaborn as sns

tips = sns.load_dataset("tips")
x= tips['day']

y=tips['total_bill']


plt.pie(y,labels=x ,explode=explode,autopct='%1.1f%%',colors=['red','green','blue','yellow'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-672225292916> in <module>()
#       9
#      10
# ---> 11 plt.pie(y,labels=x ,explode=explode,autopct='%1.1f%%',colors=['red','green','blue','yellow'])
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, data)
#    2753         wedgeprops=wedgeprops, textprops=textprops, center=center,
#    2754         frame=frame, rotatelabels=rotatelabels, **({"data": data} if
# -> 2755         data is not None else {}))
#    2756
#    2757
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# ...

# %%
#scatter plot

plt.scatter(tips['total_bill'],tips['tip'])
plt.title('scatter plot')
plt.xlabel("total label")
plt.ylabel('tips')
plt.show()

# %%
# seaborn

#to check styles available in seaborn .use matplot library

plt.style
# Out:
# <module 'matplotlib.style' from '/usr/local/lib/python3.7/dist-packages/matplotlib/style/__init__.py'>

# %%
#seaborn Implementation

plt.style.use('seaborn-white')

gender = sns.countplot(tips['sex'])

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.distplot(tips['total_bill'] )
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# scatter plot using saborn

sns.scatterplot(x='total_bill',y='tip',hue='size',data=tips,palette='summer')

# %%
#swarmp plot

sns.swarmplot(x='sex',y='total_bill',data=tips)
